# %% [markdown]
# <a href="https://colab.research.google.com/github/VikiTarasova/olist-analytics-/blob/main/notebook/olist_predict2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 3. Python: Simple Forecast and Recommendations

# %%
from IPython.lib.security import random
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

RANDOM_STATE = 42

FILE_IN = "https://raw.githubusercontent.com/VikiTarasova/olist-analytics-/refs/heads/main/data/main_sales_region.csv"

# %%
df = pd.read_csv(FILE_IN)
df.head()
# Out:
#                            order_id  ...        region
# 0  e481f51cbdc54678b7cc49136f2d6af7  ...     Southeast
# 1  e481f51cbdc54678b7cc49136f2d6af7  ...     Southeast
# 2  e481f51cbdc54678b7cc49136f2d6af7  ...     Southeast
# 3  53cdb2fc8bc7dce0b6741e2150273451  ...     Northeast
# 4  47770eb9100c2d0c44946d9cf07ec65d  ...  Central-West
#
# [5 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115723 entries, 0 to 115722
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          115723 non-null  object
#  1   order_purchase_t  115723 non-null  object
#  2   ym                115723 non-null  object
#  3   customer_state    115723 non-null  object
#  4   category_en       114062 non-null  object
#  5   price             115723 non-null  float64
#  6   freight_value     115723 non-null  float64
#  7   payment_method    115720 non-null  object
#  8   review_score      114862 non-null  float64
#  9   region            115723 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 8.8+ MB

# %%
df = df.sort_values('ym').reset_index(drop=True)
print("Month:", len(df))
df.head()
# Out:
# Month: 115723
#                            order_id  ...     region
# 0  bfbd0f9bdef84302105ad712db648a6c  ...  Southeast
# 1  bfbd0f9bdef84302105ad712db648a6c  ...  Southeast
# 2  bfbd0f9bdef84302105ad712db648a6c  ...  Southeast
# 3  85841af0d94e5d0cd3a9c0e42e565b74  ...  Southeast
# 4  dd11631d8b02780b78bd97ec44a1ca8c  ...  Southeast
#
# [5 rows x 10 columns]

# %%
df[(df.ym >= '2017-01') & (df.ym <= '2018-08')]
# Out:
#                                 order_id  ...        region
# 338     76774c936de5cb5a431120fde98e40da  ...     Southeast
# 339     8846a9571a893b22eb57d4732b978bbb  ...     Southeast
# 340     b42efbd88abf3882f91928b08cf74d6f  ...     Southeast
# 341     01ba72e24cf883d74c5479c0a626c740  ...     Southeast
# 342     452b706af12e25e6c8c740b4dc493ab0  ...     Southeast
# ...                                  ...  ...           ...
# 115718  dd787ad9c97e5504d6ea0bd294906902  ...     Southeast
# 115719  a9bcf1a7fe9234ce388f78f3902dfcae  ...     Southeast
# 115720  ad01e26d29b4818ba6299d1356a130b7  ...  Central-West
# 115721  ad8c386772f88caabcff4e2a8bee26d3  ...     Southeast
# 115722  07b1810af93ee79a38977779e7a410d0  ...     Southeast
#
# [115385 rows x 10 columns]

# %%
df = df[(df.ym >= '2017-01') & (df.ym <= '2018-08')].reset_index(drop=True)
print("Month (in process):", len(df))
display(df.head(2))
df.tail(2)
# Out:
# Month (in process): 115385
#                            order_id  ...     region
# 0  76774c936de5cb5a431120fde98e40da  ...  Southeast
# 1  8846a9571a893b22eb57d4732b978bbb  ...  Southeast
#
# [2 rows x 10 columns]
#                                 order_id  ...     region
# 115383  ad8c386772f88caabcff4e2a8bee26d3  ...  Southeast
# 115384  07b1810af93ee79a38977779e7a410d0  ...  Southeast
#
# [2 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# order_id               0
# order_purchase_t       0
# ym                     0
# customer_state         0
# category_en         1659
# price                  0
# freight_value          0
# payment_method         0
# review_score         857
# region                 0
# dtype: int64

# %%
plt.figure(figsize=(9, 4))
plt.plot(pivot.index, pivot.price, marker="o")
plt.xticks(rotation=45, ha='right')
plt.title("Monthly revenue (stable period)")
plt.tight_layout()

plt.show()

# %%
df_new = {
    't': list(range(len(pivot))),
    'ym': list(pivot.index),
    'revenue': list(pivot.price)
}
df_new = pd.DataFrame(df_new)
df_new
# Out:
#      t       ym     revenue
# 0    0  2017-01   121380.81
# 1    1  2017-02   247186.84
# 2    2  2017-03   382971.99
# 3    3  2017-04   361697.63
# 4    4  2017-05   532057.67
# 5    5  2017-06   445704.24
# 6    6  2017-07   518693.58
# 7    7  2017-08   583908.40
# 8    8  2017-09   647053.47
# 9    9  2017-10   680569.27
# 10  10  2017-11  1031580.23
# 11  11  2017-12   755290.44
# 12  12  2018-01   967405.31
# 13  13  2018-02   870151.32
# 14  14  2018-03   998312.12
# 15  15  2018-04  1008524.96
# 16  16  2018-05  1013168.64
# 17  17  2018-06   900971.61
# 18  18  2018-07   899483.93
# 19  19  2018-08   868406.93

# %%
list(pivot.index)
# Out:
# ['2017-01',
#  '2017-02',
#  '2017-03',
#  '2017-04',
#  '2017-05',
#  '2017-06',
#  '2017-07',
#  '2017-08',
#  '2017-09',
#  '2017-10',
#  '2017-11',
#  '2017-12',
#  '2018-01',
#  '2018-02',
#  '2018-03',
#  '2018-04',
#  '2018-05',
#  '2018-06',
#  '2018-07',
#  '2018-08']

# %%
plt.figure(figsize=(9, 4))
plt.plot(df.ym, df.price, marker="o")
plt.xticks(rotation=45, ha='right')

plt.show()

# %%
pivot = df.pivot_table(
    values='price',
    index='ym',
    aggfunc='sum'
)

pivot
# Out:
#               price
# ym
# 2017-01   121380.81
# 2017-02   247186.84
# 2017-03   382971.99
# 2017-04   361697.63
# 2017-05   532057.67
# 2017-06   445704.24
# 2017-07   518693.58
# 2017-08   583908.40
# 2017-09   647053.47
# 2017-10   680569.27
# 2017-11  1031580.23
# 2017-12   755290.44
# 2018-01   967405.31
# 2018-02   870151.32
# 2018-03   998312.12
# 2018-04  1008524.96
# 2018-05  1013168.64
# 2018-06   900971.61
# 2018-07   899483.93
# 2018-08   868406.93

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
X = df_new[['t']]
y = df_new['revenue']
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=RANDOM_STATE
)
model = LinearRegression().fit(X_train, y_train)
next_index = len(df_new)
y_pred = model.predict(X_test)
forecast = model.predict(pd.DataFrame({
    't': [next_index]
}))[0]
print(f"Predict revenue for next month: R${forecast:,.0f}")
print(f"Average growth for month: R${model.coef_[0]:,.0f}")
print("-" * 15)
print(f"MAE: R${mean_absolute_error(y_test, y_pred):,.0f}")
print(f"RMSE: R${np.sqrt(mean_squared_error(y_test, y_pred)):,.0f}")
print(f"Predict accuracy (R2): {r2_score(y_test, y_pred):.1%}")
# Out:
# Predict revenue for next month: R$1,109,031
# Average growth for month: R$37,963
# ---------------
# MAE: R$138,100
# RMSE: R$148,958
# Predict accuracy (R2): 85.4%

# %%
df_new["month"] = df_new['ym'].str[-2:]
season = df_new.groupby("month")["revenue"].mean().round(0)
print("Average growth for number month:")
print(season.sort_values(ascending=False))
# Out:
# Average growth for number month:
# month
# 11    1031580.0
# 05     772613.0
# 12     755290.0
# 08     726158.0
# 07     709089.0
# 03     690642.0
# 04     685111.0
# 10     680569.0
# 06     673338.0
# 09     647053.0
# 02     558669.0
# 01     544393.0
# Name: revenue, dtype: float64
